# %%
import pandas as pd 
import os
import glob
import datetime, warnings, scipy 
import numpy as np
import seaborn as sea
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import ConnectionPatch
from collections import OrderedDict
from matplotlib.gridspec import GridSpec
from mpl_toolkits.basemap import Basemap
from sklearn import metrics, linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from scipy.optimize import curve_fit
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
path = "/Users/xiomaragonzalez/Desktop/train_2019.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    AIRLINE_ID            CARRIER_NAME  ORIGIN_AIRPORT_ID ORIGIN  \
# 0       19805  American Airlines Inc.              14107    PHX
# 1       19393  Southwest Airlines Co.              14107    PHX
# 2       19393  Southwest Airlines Co.              14107    PHX
# 3       19393  Southwest Airlines Co.              14107    PHX
# 4       19393  Southwest Airlines Co.              14107    PHX
#
#   ORIGIN_CITY_NAME PREVIOUS_AIRPORT  LATITUDE  LONGITUDE  MONTH  DAY_OF_MONTH  \
# 0      Phoenix, AZ             NONE    33.436   -112.009      1            20
# 1      Phoenix, AZ             NONE    33.436   -112.009      1            20
# 2      Phoenix, AZ             NONE    33.436   -112.009      1            20
# 3      Phoenix, AZ             NONE    33.436   -112.009      1            20
# 4      Phoenix, AZ             NONE    33.436   -112.009      1            20
#
#    AIRPORT_FLIGHTS_MONTH  SEGMENT_NUMBER TAIL_NUM  MANUFACTURE_YEAR  \
# 0                  14576               1   N509AY            2009.0
# 1                  14576               1   N8706W            2017.0
# 2                  14576               1   N469WN            2004.0
# 3                  14576               1   N713SW            1998.0
# 4                  14576               1   N8321D            2012.0
#
#    PLANE_AGE  AWND  PRCP  SNOW  TMAX  TAVG  DEST_AIRPORT_ID DEST  \
# 0         10  3.36   0.0   NaN  74.0  58.0            13930  ORD
# 1          2  3.36   0.0   NaN  74.0  58.0            13232  MDW
# 2         15  3.36   0.0   NaN  74.0  58.0            14679  SAN
# 3         21  3.36   0.0   NaN  74.0  58.0            14869  SLC
# 4          7  3.36   0.0   NaN  74.0  58.0            14771  SFO
#
#        DEST_CITY_NAME                 DEPARTING_AIRPORT  CRS_DEP_TIME  \
# 0         Chicago, IL  Phoenix Sky Harbor International           800
# 1         Chicago, IL  Phoenix Sky Harbor International           715
# 2       San Diego, CA  Phoenix Sky Harbor International           710
# 3  Salt Lake City, UT  Phoenix Sky Harbor International           755
# 4   San Francisco, CA  Phoenix Sky Harbor International          1005
#
#    DEP_TIME  DEP_DELAY_NEW  CRS_ARR_TIME  ARR_TIME  ARR_DELAY_NEW  CANCELLED  \
# 0     759.0            0.0          1226    1228.0            2.0        0.0
# 1     810.0           55.0          1130    1213.0           43.0        0.0
# 2     703.0            0.0           725     710.0            0.0        0.0
# 3     749.0            0.0           930     914.0            0.0        0.0
# 4    1000.0            0.0          1130    1111.0            0.0        0.0
#
#    DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0    1440.0            NaN            NaN        NaN             NaN
# 1    1444.0           43.0            0.0        0.0             0.0
# 2     304.0            NaN            NaN        NaN             NaN
# 3     507.0            NaN            NaN        NaN             NaN
# 4     651.0            NaN            NaN        NaN             NaN
#
#    LATE_AIRCRAFT_DELAY
# 0                  NaN
# 1                  0.0
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
core30 = data['ORIGIN'].unique()
airlines = data['CARRIER_NAME'].unique()
airport_airline_matrix = pd.DataFrame(core30)
airport_airline_matrix.set_index(0, inplace=True)

for a in airlines:
    data_airline = data[data['CARRIER_NAME'] == a]
    delay_by_origin = data_airline['DEP_DELAY_NEW'].groupby(data['ORIGIN']).mean()
    airport_airline_matrix[a] = delay_by_origin

airport_airline_matrix
# Out:
#      American Airlines Inc.  Southwest Airlines Co.  SkyWest Airlines Inc.  \
# 0
# PHX               12.796700               14.632579               9.175787
# PHL               14.958531               12.895018              15.252226
# EWR               17.643064               22.017374              28.665568
# CLT               16.394967               13.493425              28.247879
# MDW                     NaN               17.075298              14.043845
# MCO               16.995201               14.780986                    NaN
# SEA               16.082835               13.216130              11.270936
# IAD               14.461266                9.700623              16.643723
# JFK               12.542661                     NaN              29.308194
# SAN               13.208824               11.738646              10.947738
# LGA               14.808898               21.282173              26.814116
# SFO               17.298251               14.788113              15.790378
# MEM               14.239158               11.305932              20.792021
# BOS               14.863745               13.539820              14.680529
# FLL               15.613857               12.943865                    NaN
# TPA               13.439845               12.431462                    NaN
# DCA               13.538987               11.223109              25.086406
# DEN               18.802160               15.635897              15.053479
# IAH               17.595546                     NaN              19.775823
# MIA               16.654768                     NaN                    NaN
# LAX               16.449320               14.844364              11.353065
# DFW               18.167246                     NaN              17.897338
# LAS               17.091070               13.670731              11.172727
# ORD               17.763679                     NaN              20.750807
# BWI               13.542254               15.030083              16.247863
# MSP               15.104092               11.657360              15.905178
# SLC               14.888359               10.587106              14.684516
# ATL               12.727707               14.428372              24.896078
# HNL               13.472260                     NaN                    NaN
# DTW               12.367950                9.534976              18.405007
#
#      Frontier Airlines Inc.  Mesa Airlines Inc.  United Air Lines Inc.  \
# 0
# PHX               16.505000           16.285030              14.837566
# PHL               26.152104           14.754501              18.228885
# EWR               32.716535                 NaN              23.687051
# CLT               22.659091           14.817984              23.914491
# MDW                     NaN                 NaN                    NaN
# MCO               21.679256                 NaN              18.248688
# SEA               23.757522                 NaN              14.449281
# IAD               18.952471           21.146019              13.085411
# JFK                     NaN                 NaN                    NaN
# SAN               18.884651                 NaN              14.726638
# LGA               27.154023           30.032587              20.148199
# SFO               27.964346                 NaN              16.346642
# MEM               17.360465           14.391620              11.448366
# BOS               18.099576           13.913043              18.342780
# FLL               31.864151            4.294118              20.327930
# TPA               22.557681            7.981818              17.522727
# DCA               12.768075           27.237134              13.513789
# DEN               20.712834                 NaN              16.033365
# IAH               23.263858           17.669492              16.072682
# MIA               23.548223           27.286957              22.620991
# LAX               16.344867                 NaN              11.519885
# DFW               20.382105           20.059681              22.261348
# LAS               23.655829                 NaN              13.683565
# ORD               24.182866                 NaN              18.285298
# BWI               23.996441                 NaN              12.043008
# MSP               17.248084           21.522646              18.131040
# SLC               13.919032           18.277929              25.771495
# ATL               21.880233           17.698167              24.150606
# HNL                     NaN                 NaN              13.178813
# DTW               16.628205           18.686469              15.261238
#
#      JetBlue Airways  Alaska Airlines Inc.  Delta Air Lines Inc.  Comair Inc.  \
# 0
# PHX        30.356938              8.928228              9.441338          NaN
# PHL        25.762040             13.423077             12.468550    14.772806
# EWR        33.046523             17.160806             23.171213          NaN
# CLT        31.744315                   NaN             10.989395    10.974636
# MDW              NaN                   NaN              7.825433          NaN
# MCO        30.265663             11.917899             13.334842          NaN
# SEA        22.158358             10.963153             10.724021          NaN
# IAD        12.285714             14.616004              9.002562    13.144654
# JFK        18.620668             13.555530             18.221893    12.429907
# SAN        18.588765             11.849668              8.435892          NaN
# LGA        27.664275                   NaN             21.721241          NaN
# SFO        18.985665             13.788227             14.152834          NaN
# MEM              NaN                   NaN              8.193822     9.487365
# BOS        21.305702             13.719036             17.269603    17.894737
# FLL        27.662774             15.135678             14.509069          NaN
# TPA        27.498924             10.362613             13.170354          NaN
# DCA        24.760692              9.478980             10.550663    14.581950
# DEN        26.615780             12.812969             11.566633          NaN
# IAH        50.265152             12.338906             23.002765    12.722772
# MIA              NaN                   NaN             16.883975          NaN
# LAX        14.990083             12.570417             12.279350          NaN
# DFW        26.636800             11.738636             20.401763          NaN
# LAS        26.439512             12.706563              8.929503          NaN
# ORD        35.392706             17.711612             23.205000          NaN
# BWI        20.374863             12.360972             10.536617     8.625000
# MSP        22.021804             10.044209             11.773842          NaN
# SLC        29.496023              7.000920             10.850009          NaN
# ATL        25.106639             11.986301             12.111326    14.813571
# HNL              NaN             10.448067              9.303458          NaN
# DTW        16.596507              7.074468             12.043347    14.597434
#
#      Atlantic Southeast Airlines  American Eagle Airlines Inc.
# 0
# PHX                          NaN                           NaN
# PHL                     5.375000                      8.976744
# EWR                    25.875199                     16.915289
# CLT                    28.402098                           NaN
# MDW                          NaN                           NaN
# MCO                          NaN                           NaN
# SEA                          NaN                           NaN
# IAD                    15.166667                           NaN
# JFK                          NaN                     16.039451
# SAN                          NaN                           NaN
# LGA                    13.968000                     18.124542
# SFO                          NaN                           NaN
# MEM                    29.491950                     18.564092
# BOS                    10.733333                      9.753846
# FLL                          NaN                           NaN
# TPA                          NaN                           NaN
# DCA                    33.562061                      0.000000
# DEN                          NaN                           NaN
# IAH                    11.480346                     14.320339
# MIA                          NaN                      4.614428
# LAX                          NaN                           NaN
# DFW                    24.507937                      6.235849
# LAS                          NaN                           NaN
# ORD                    18.891041                     11.202720
# BWI                          NaN                     22.079347
# MSP                    19.196429                     17.682171
# SLC                    16.256410                           NaN
# ATL                    11.391393                     22.550617
# HNL                          NaN                           NaN
# DTW                    25.113725                     24.964113

# %%
fig = plt.figure(1, figsize = (15,10))
fig.suptitle('Origin Airport Impact on Dealy')

left_airports = airport_airline_matrix.iloc[:15]
right_airports = airport_airline_matrix.iloc[15:]
max_delay = airport_airline_matrix.melt().value.max()

ax0 = fig.add_subplot(1,2,1)
sea.heatmap(left_airports, linewidths=0.01, cmap="Accent", vmin=0, vmax=max_delay)
plt.setp(ax0.get_xticklabels(), fontsize=20, rotation=85)
plt.setp(ax0.get_yticklabels(), fontsize=20, rotation=0)
ax0.yaxis.label.set_visible(False)

ax1 = fig.add_subplot(1,2,2)
sea.heatmap(right_airports, linewidths=0.01, cmap="Accent", vmin=0, vmax=max_delay)
plt.setp(ax1.get_xticklabels(), fontsize=20, rotation=85)
plt.setp(ax1.get_yticklabels(), fontsize=20, rotation=0)
ax1.yaxis.label.set_visible(False)
