# %%
import numpy as np
import pandas as pd
from numpy import array
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.feature_selection import SelectKBest,f_classif,chi2,f_regression

# %%
class DataPreprocess:
    def __init__(self, filename):
        self.filename = filename
        
    def read_in_data(self):
        return pd.read_csv(self.filename)

    def select_feature_manually(self):
        self.df = self.read_in_data()
        self.df_feature = self.df[["AIRLINE_ID", "ORIGIN_AIRPORT_ID", "DEST_AIRPORT_ID","LATITUDE", "LONGITUDE", "MONTH","DAY_OF_MONTH", "PLANE_AGE", "AWND", "PRCP", "SNOW", "TMAX", "TAVG",
             "CRS_DEP_TIME", "CRS_ARR_TIME", "DISTANCE"]]

    def convert_time(self, time):
        hour = np.floor(time/100)
        minutes = hour*60 + time - hour*100
        return minutes

    def make_dataset(self):
        airline_oh = pd.get_dummies(self.df_feature['AIRLINE_ID'])
        name = 'AIRLINE_ID'
        airline_oh_columns = []
        for i in range(airline_oh.shape[1]):
            airline_oh_columns.append(name+" "+str(i))
        
        airline = pd.DataFrame(airline_oh.to_numpy(),columns=airline_oh_columns)
        self.df_feature = self.df_feature.join(airline)
            
        arr_airport_oh = pd.get_dummies(self.df_feature['DEST_AIRPORT_ID'])
        name = 'DEST_AIRPORT_ID'
        arr_airport_oh_columns = []
        for i in range(arr_airport_oh.shape[1]):
            arr_airport_oh_columns.append(name+" "+str(i))
            
        arr_airport = pd.DataFrame(arr_airport_oh.to_numpy(),columns=arr_airport_oh_columns)
        self.df_feature = self.df_feature.join(arr_airport)
            
        dep_airport_oh = pd.get_dummies(self.df_feature['ORIGIN_AIRPORT_ID'])
        name = 'ORIGIN_AIRPORT_ID'
        dep_airport_oh_columns = []
        for i in range(dep_airport_oh.shape[1]):
            dep_airport_oh_columns.append(name+" "+str(i))
            
        dep_airport = pd.DataFrame(dep_airport_oh.to_numpy(),columns=dep_airport_oh_columns)
        self.df_feature = self.df_feature.join(dep_airport)

#         airline_oh = airline_oh_df.to_numpy()
#         arr_airport_oh = arr_airport_oh_df.to_numpy()
#         dep_airport_oh = dep_airport_oh_df.to_numpy()

        self.df_feature = self.df_feature.drop(['AIRLINE_ID', 'DEST_AIRPORT_ID', 'ORIGIN_AIRPORT_ID'], axis=1)

        self.df_feature = self.df_feature.fillna(0)

        arr_time = self.df_feature["CRS_ARR_TIME"].to_numpy().reshape(-1, 1)
        dep_time = self.df_feature["CRS_DEP_TIME"].to_numpy().reshape(-1, 1)
        arr_time_min = self.convert_time(arr_time)
        dep_time_min = self.convert_time(dep_time)
        time_min_df = pd.DataFrame(np.hstack([arr_time_min, dep_time_min]), columns=['CRS_ARR_TIME_MIN', 'CRS_DEP_TIME_MIN'])

        self.df_feature = self.df_feature.drop(["CRS_ARR_TIME", "CRS_DEP_TIME"], axis=1)
        self.df_feature = self.df_feature.join(time_min_df)

        features_without_id = self.df_feature.to_numpy()
        self.features = features_without_id # array
        self.df_truth = self.df[["CANCELLED", "DEP_DELAY_NEW", "ARR_DELAY_NEW"]]
    
    
    def generate(self):

        self.select_feature_manually()
        self.make_dataset()
    

        y = np.zeros((self.df_truth.shape[0],2))

        for i in range(6):
            if i==0:
                y[self.df_truth["DEP_DELAY_NEW"]==0, 0] = 0
                y[self.df_truth["ARR_DELAY_NEW"]==0, 1] = 0
            elif i==5:
                ub = (i-1)*15
                y[self.df_truth["DEP_DELAY_NEW"]>ub, 0] = ub
                y[self.df_truth["ARR_DELAY_NEW"]>ub, 1] = ub
            else: 
                lb = (i-1)*15
                ub = i*15
                y[np.logical_and(self.df_truth["DEP_DELAY_NEW"]>lb, self.df_truth["DEP_DELAY_NEW"]<=ub), 0] = lb
                y[np.logical_and(self.df_truth["ARR_DELAY_NEW"]>lb, self.df_truth["ARR_DELAY_NEW"]<=ub), 1] = lb       

        y = pd.DataFrame(y, columns=['dep','arr'])        
        
        return self.df_feature, self.features, self.df_truth, y

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def select_K_Best(X,y,method,num_features):
    if method == "clf":
        select = SelectKBest(f_classif,k=num_features)
        z = select.fit_transform(X,y)
        filter = select.get_support(1)
        X_new = X[X.columns[filter]]
        selected_fs = X_new.columns
        return selected_fs,z
    else:
        select = SelectKBest(f_regression,k=num_features)
        z = select.fit_transform(X,y)
        filter = select.get_support(1)
        X_new = X[X.columns[filter]]
        selected_fs = X_new.columns
        return selected_fs,z

# %%
filename = "./Data/train_2019.csv"
data = DataPreprocess(filename)
X, _, y_truth, y = data.generate()

# %%
FEATURE_NUM = 10
features_clf,z_clf = select_K_Best(X,y["dep"],"clf",FEATURE_NUM)
features_reg,z_reg = select_K_Best(X,y["dep"],"reg",FEATURE_NUM)

# %%
X_input = X[features_clf]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_input, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
X.shape
# Out:
# (2216748, 85)

# %% [markdown]
# # Select K Best - Departure

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

error_table = np.empty((0,4))

for i in range(1,X.shape[1]+1):
    FEATURE_NUM = i
    print("# of feature:",str(i))
    features_dep,z_clf = select_K_Best(X,y["dep"],"clf",FEATURE_NUM)
    X_input = X[features_dep]
    X_train, X_test, y_train, y_test = train_test_split(X_input, y["dep"], test_size=0.3, random_state=1) # 70% training and 30% test
    
    rf_dep = RandomForestClassifier(n_estimators=20)
    rf_dep.fit(X_train, y_train)
    # make a single prediction
    y_pred = rf_dep.predict(X_test)
    # Calculate the absolute errors
    error_rate = len(y_pred[y_pred!=y_test])/len(y_pred)
    print("Error Rate:", error_rate)

    train_accuracy = accuracy_score(y_train,rf_dep.predict(X_train))*100
    print("Accuracy for our training dataset with tuning is : {:.2f}%".format(train_accuracy) )

    test_accuracy = accuracy_score(y_test,y_pred)*100
    print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
    
    error_table = np.vstack((error_table, np.array([i, error_rate, train_accuracy, test_accuracy])))
# Out:
# # of feature: 1
# Error Rate: 0.20408556069320702
# Accuracy for our training dataset with tuning is : 79.70%
# Accuracy for our testing dataset with tuning is : 79.59%
# # of feature: 2
# Error Rate: 0.207301981128529
# Accuracy for our training dataset with tuning is : 79.98%
# Accuracy for our testing dataset with tuning is : 79.27%
# # of feature: 3
# Error Rate: 0.21534077666253149
# Accuracy for our training dataset with tuning is : 85.99%
# Accuracy for our testing dataset with tuning is : 78.47%
# # of feature: 4
# Error Rate: 0.21478891770986053
# Accuracy for our training dataset with tuning is : 86.25%
# Accuracy for our testing dataset with tuning is : 78.52%
# # of feature: 5
# Error Rate: 0.21476636216683584
# Accuracy for our training dataset with tuning is : 86.39%
# Accuracy for our testing dataset with tuning is : 78.52%
# # of feature: 6
# Error Rate: 0.21396188113228826
# Accuracy for our training dataset with tuning is : 86.48%
# Accuracy for our testing dataset with tuning is : 78.60%
# # of feature: 7
# Error Rate: 0.21399345889252283
# Accuracy for our training dataset with tuning is : 86.52%
# Accuracy for our testing dataset with tuning is : 78.60%
# # of feature: 8
# Error Rate: 0.21397992556670803
# Accuracy for our training dataset with tuning is : 86.54%
# Accuracy for our testing dataset with tuning is : 78.60%
# # of feature: 9
# Error Rate: 0.22215555806172702
# Accuracy for our training dataset with tuning is : 94.89%
# Accuracy for our testing dataset with tuning is : 77.78%
# # of feature: 10
# Error Rate: 0.22226983947971882
# Accuracy for our training dataset with tuning is : 94.90%
# Accuracy for our testing dataset with tuning is : 77.77%
# # of feature: 11
# Error Rate: 0.222006691477764
# Accuracy for our training dataset with tuning is : 94.93%
# Accuracy for our testing dataset with tuning is : 77.80%
# # of feature: 12
# Error Rate: 0.22249088380136084
# Accuracy for our training dataset with tuning is : 95.44%
# Accuracy for our testing dataset with tuning is : 77.75%
# # of feature: 13
# Error Rate: 0.22291492801022517
# Accuracy for our training dataset with tuning is : 95.45%
# Accuracy for our testing dataset with tuning is : 77.71%
# # of feature: 14
# Error Rate: 0.223202135258073
# Accuracy for our training dataset with tuning is : 95.45%
# Accuracy for our testing dataset with tuning is : 77.68%
# # of feature: 15
# Error Rate: 0.2233840833051389
# Accuracy for our training dataset with tuning is : 95.45%
# Accuracy for our testing dataset with tuning is : 77.66%
# # of feature: 16
# Error Rate: 0.22355700913499493
# Accuracy for our training dataset with tuning is : 95.46%
# Accuracy for our testing dataset with tuning is : 77.64%
# # of feature: 17
# Error Rate: 0.22355099432352168
# Accuracy for our training dataset with tuning is : 95.46%
# Accuracy for our testing dataset with tuning is : 77.64%
# # of feature: 18
# Error Rate: 0.22489380098492537
# Accuracy for our training dataset with tuning is : 95.45%
# Accuracy for our testing dataset with tuning is : 77.51%
# # of feature: 19
# Error Rate: 0.2243945716326454
# Accuracy for our training dataset with tuning is : 95.46%
# Accuracy for our testing dataset with tuning is : 77.56%
# # of feature: 20
# Error Rate: 0.22455997894815985
# Accuracy for our training dataset with tuning is : 95.45%
# Accuracy for our testing dataset with tuning is : 77.54%
# # of feature: 21
# Error Rate: 0.1941776624938912
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.58%
# # of feature: 22
# Error Rate: 0.19460621781136048
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.54%
# # of feature: 23
# Error Rate: 0.19440021051840156
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.56%
# # of feature: 24
# Error Rate: 0.1945746400511259
# Accuracy for our training dataset with tuning is : 98.76%
# Accuracy for our testing dataset with tuning is : 80.54%
# # of feature: 25
# Error Rate: 0.1945731363482576
# Accuracy for our training dataset with tuning is : 98.76%
# Accuracy for our testing dataset with tuning is : 80.54%
# # of feature: 26
# Error Rate: 0.19473703996090372
# Accuracy for our training dataset with tuning is : 98.76%
# Accuracy for our testing dataset with tuning is : 80.53%
# # of feature: 27
# Error Rate: 0.19460772151422878
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.54%
# # of feature: 28
# Error Rate: 0.19487538062478854
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.51%
# # of feature: 29
# Error Rate: 0.19488741024773504
# Accuracy for our training dataset with tuning is : 98.76%
# Accuracy for our testing dataset with tuning is : 80.51%
# # of feature: 30
# Error Rate: 0.19478666215555807
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.52%
# # of feature: 31
# Error Rate: 0.1947580918010601
# Accuracy for our training dataset with tuning is : 98.77%
# Accuracy for our testing dataset with tuning is : 80.52%
# # of feature: 32
# Error Rate: 0.18480207510995827
# Accuracy for our training dataset with tuning is : 99.13%
# Accuracy for our testing dataset with tuning is : 81.52%
# # of feature: 33
# Error Rate: 0.18526070448479381
# Accuracy for our training dataset with tuning is : 99.14%
# Accuracy for our testing dataset with tuning is : 81.47%
# # of feature: 34
# Error Rate: 0.1849298898537649
# Accuracy for our training dataset with tuning is : 99.12%
# Accuracy for our testing dataset with tuning is : 81.51%
# # of feature: 35
# Error Rate: 0.18519454155858803
# Accuracy for our training dataset with tuning is : 99.13%
# Accuracy for our testing dataset with tuning is : 81.48%
# # of feature: 36
# Error Rate: 0.1813360399984963
# Accuracy for our training dataset with tuning is : 99.20%
# Accuracy for our testing dataset with tuning is : 81.87%
# # of feature: 37
# Error Rate: 0.18178715085899028
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.82%
# # of feature: 38
# Error Rate: 0.1817119657155746
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.83%
# # of feature: 39
# Error Rate: 0.18161422502913424
# Accuracy for our training dataset with tuning is : 99.20%
# Accuracy for our testing dataset with tuning is : 81.84%
# # of feature: 40
# Error Rate: 0.1814292695763317
# Accuracy for our training dataset with tuning is : 99.20%
# Accuracy for our testing dataset with tuning is : 81.86%
# # of feature: 41
# Error Rate: 0.18161572873200255
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.84%
# # of feature: 42
# Error Rate: 0.1814488177136198
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.86%
# # of feature: 43
# Error Rate: 0.18155708432013834
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.84%
# # of feature: 44
# Error Rate: 0.1816533213037104
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.83%
# # of feature: 45
# Error Rate: 0.18147889177098606
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.85%
# # of feature: 46
# Error Rate: 0.18129393631818352
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.87%
# # of feature: 47
# Error Rate: 0.1813134844554716
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.87%
# # of feature: 48
# Error Rate: 0.18111800308259088
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.89%
# # of feature: 49
# Error Rate: 0.18064584038194054
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.94%
# # of feature: 50
# Error Rate: 0.18082026991466485
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.92%
# # of feature: 51
# Error Rate: 0.18088492913800233
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.91%
# # of feature: 52
# Error Rate: 0.18089695876094883
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.91%
# # of feature: 53
# Error Rate: 0.1806533588962821
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.93%
# # of feature: 54
# Error Rate: 0.18074207736551257
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.93%
# # of feature: 55
# Error Rate: 0.18098718093304764
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.90%
# # of feature: 56
# Error Rate: 0.18032104056238488
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.97%
# # of feature: 57
# Error Rate: 0.18055261080410512
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.94%
# # of feature: 58
# Error Rate: 0.18082026991466485
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.92%
# # of feature: 59
# Error Rate: 0.18059020337581294
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.94%
# # of feature: 60
# Error Rate: 0.18039472200293222
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.96%
# # of feature: 61
# Error Rate: 0.18047892936355775
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.95%
# # of feature: 62
# Error Rate: 0.18009548513213788
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.99%
# # of feature: 63
# Error Rate: 0.18046539603774295
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.95%
# # of feature: 64
# Error Rate: 0.1809180106011052
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.91%
# # of feature: 65
# Error Rate: 0.18043682568324498
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.96%
# # of feature: 66
# Error Rate: 0.181032292019097
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.90%
# # of feature: 67
# Error Rate: 0.18106988459080486
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.89%
# # of feature: 68
# Error Rate: 0.1809150031953686
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.91%
# # of feature: 69
# Error Rate: 0.18100522536746738
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.90%
# # of feature: 70
# Error Rate: 0.18116912898011353
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.88%
# # of feature: 71
# Error Rate: 0.1811661215743769
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.88%
# # of feature: 72
# Error Rate: 0.1809255291154468
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.91%
# # of feature: 73
# Error Rate: 0.18133754370136462
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.87%
# # of feature: 74
# Error Rate: 0.18156159542874328
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.84%
# # of feature: 75
# Error Rate: 0.1813691214615992
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.86%
# # of feature: 76
# Error Rate: 0.18086688470358256
# Accuracy for our training dataset with tuning is : 99.22%
# Accuracy for our testing dataset with tuning is : 81.91%
# # of feature: 77
# Error Rate: 0.1811074771625127
# Accuracy for our training dataset with tuning is : 99.21%
# Accuracy for our testing dataset with tuning is : 81.89%
# # of feature: 78
# Error Rate: 0.18084132175482126
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.92%
# # of feature: 79
# Error Rate: 0.18122476598624113
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.88%
# # of feature: 80
# Error Rate: 0.18165181760084206
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.83%
# # of feature: 81
# Error Rate: 0.1769452276230217
# Accuracy for our training dataset with tuning is : 99.29%
# Accuracy for our testing dataset with tuning is : 82.31%
# # of feature: 82
# Error Rate: 0.17665651667230556
# Accuracy for our training dataset with tuning is : 99.28%
# Accuracy for our testing dataset with tuning is : 82.33%
# # of feature: 83
# Error Rate: 0.176797864741927
# Accuracy for our training dataset with tuning is : 99.28%
# Accuracy for our testing dataset with tuning is : 82.32%
# # of feature: 84
# Error Rate: 0.17654373895718206
# Accuracy for our training dataset with tuning is : 99.29%
# Accuracy for our testing dataset with tuning is : 82.35%
# # of feature: 85
# Error Rate: 0.17685199804518628
# Accuracy for our training dataset with tuning is : 99.28%
# Accuracy for our testing dataset with tuning is : 82.31%

# %%
plt.plot(
    error_table[:,0],
    error_table[:,1],
    label="Error Rate"
)
plt.ylabel('Error Rate')
plt.xlabel('# of best feature')
# Out:
# Text(0.5, 0, '# of best feature')

# %%
error_table[np.argmin(error_table[:,1]),:]
# Out:
# array([84.        ,  0.17654374, 99.28853281, 82.3456261 ])

# %%
FEATURE_NUM = 84
features_dep,z_clf = select_K_Best(X,y["dep"],"clf",FEATURE_NUM)
X_input = X[features_dep]
X_train, X_test, y_train, y_test = train_test_split(X_input, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
print("Selected Top",FEATURE_NUM," Features for Classification :",list(features_dep))
# Out:
# Selected Top 84  Features for Classification : ['LATITUDE', 'LONGITUDE', 'MONTH', 'DAY_OF_MONTH', 'PLANE_AGE', 'AWND', 'PRCP', 'SNOW', 'TMAX', 'TAVG', 'DISTANCE', 'AIRLINE_ID 0', 'AIRLINE_ID 1', 'AIRLINE_ID 2', 'AIRLINE_ID 3', 'AIRLINE_ID 4', 'AIRLINE_ID 5', 'AIRLINE_ID 6', 'AIRLINE_ID 7', 'AIRLINE_ID 9', 'AIRLINE_ID 10', 'AIRLINE_ID 11', 'DEST_AIRPORT_ID 0', 'DEST_AIRPORT_ID 1', 'DEST_AIRPORT_ID 2', 'DEST_AIRPORT_ID 3', 'DEST_AIRPORT_ID 4', 'DEST_AIRPORT_ID 5', 'DEST_AIRPORT_ID 6', 'DEST_AIRPORT_ID 7', 'DEST_AIRPORT_ID 8', 'DEST_AIRPORT_ID 9', 'DEST_AIRPORT_ID 10', 'DEST_AIRPORT_ID 11', 'DEST_AIRPORT_ID 12', 'DEST_AIRPORT_ID 13', 'DEST_AIRPORT_ID 14', 'DEST_AIRPORT_ID 15', 'DEST_AIRPORT_ID 16', 'DEST_AIRPORT_ID 17', 'DEST_AIRPORT_ID 18', 'DEST_AIRPORT_ID 19', 'DEST_AIRPORT_ID 20', 'DEST_AIRPORT_ID 21', 'DEST_AIRPORT_ID 22', 'DEST_AIRPORT_ID 23', 'DEST_AIRPORT_ID 24', 'DEST_AIRPORT_ID 25', 'DEST_AIRPORT_ID 26', 'DEST_AIRPORT_ID 27', 'DEST_AIRPORT_ID 28', 'DEST_AIRPORT_ID 29', 'ORIGIN_AIRPORT_ID 0', 'ORIGIN_AIRPORT_ID 1', 'ORIGIN_AIRPORT_ID 2', 'ORIGIN_AIRPORT_ID 3', 'ORIGIN_AIRPORT_ID 4', 'ORIGIN_AIRPORT_ID 5', 'ORIGIN_AIRPORT_ID 6', 'ORIGIN_AIRPORT_ID 7', 'ORIGIN_AIRPORT_ID 8', 'ORIGIN_AIRPORT_ID 9', 'ORIGIN_AIRPORT_ID 10', 'ORIGIN_AIRPORT_ID 11', 'ORIGIN_AIRPORT_ID 12', 'ORIGIN_AIRPORT_ID 13', 'ORIGIN_AIRPORT_ID 14', 'ORIGIN_AIRPORT_ID 15', 'ORIGIN_AIRPORT_ID 16', 'ORIGIN_AIRPORT_ID 17', 'ORIGIN_AIRPORT_ID 18', 'ORIGIN_AIRPORT_ID 19', 'ORIGIN_AIRPORT_ID 20', 'ORIGIN_AIRPORT_ID 21', 'ORIGIN_AIRPORT_ID 22', 'ORIGIN_AIRPORT_ID 23', 'ORIGIN_AIRPORT_ID 24', 'ORIGIN_AIRPORT_ID 25', 'ORIGIN_AIRPORT_ID 26', 'ORIGIN_AIRPORT_ID 27', 'ORIGIN_AIRPORT_ID 28', 'ORIGIN_AIRPORT_ID 29', 'CRS_ARR_TIME_MIN', 'CRS_DEP_TIME_MIN']

# %% [markdown]
# ## Adaboost
# https://www.datacamp.com/community/tutorials/adaboost-classifier-python <br>
# https://scikit-learn.org/stable/auto_examples/ensemble/plot_adaboost_hastie_10_2.html#sphx-glr-auto-examples-ensemble-plot-adaboost-hastie-10-2-py

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### Base learner: Decision Tree

# %% [markdown]
# #### 1. Departure

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
model = abc.fit(X_train, y_train["dep"])

#Predict the response for test dataset
y_pred = model.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test["dep"], y_pred))
# Out:
# Accuracy: 0.796260290966505

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test["dep"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Departure)')
# Out:
# Confusion matrix, without normalization
# [[528993      0      0      0    314]
#  [ 44930      0      0      0    116]
#  [ 24672      0      0      0     69]
#  [ 15964      0      0      0     71]
#  [ 49356      0      0      0    540]]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import zero_one_loss
from sklearn.ensemble import AdaBoostClassifier

name = "dep"

n_estimators = 400
learning_rate = 0.5

dt_stump = DecisionTreeClassifier(max_depth=1, min_samples_leaf=1)
dt_stump.fit(X_train, y_train[name])
dt_stump_err = 1.0 - dt_stump.score(X_test, y_test[name])

dt = DecisionTreeClassifier(max_depth=9, min_samples_leaf=1)
dt.fit(X_train, y_train[name])
dt_err = 1.0 - dt.score(X_test, y_test[name])


ada_real = AdaBoostClassifier(
    base_estimator=dt_stump,
    learning_rate=learning_rate,
    n_estimators=n_estimators,
    algorithm="SAMME.R",
)
ada_real.fit(X_train, y_train[name])

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot([1, n_estimators], [dt_stump_err] * 2, "k-", label="Decision Stump Error")
ax.plot([1, n_estimators], [dt_err] * 2, "k--", label="Decision Tree Error")

ada_real_err = np.zeros((n_estimators,))
for i, y_pred in enumerate(ada_real.staged_predict(X_test)):
    ada_real_err[i] = zero_one_loss(y_pred, y_test[name])

ada_real_err_train = np.zeros((n_estimators,))
for i, y_pred in enumerate(ada_real.staged_predict(X_train)):
    ada_real_err_train[i] = zero_one_loss(y_pred, y_train[name])


ax.plot(
    np.arange(n_estimators) + 1,
    ada_real_err,
    label="AdaBoost Test Error",
    color="orange",
)
ax.plot(
    np.arange(n_estimators) + 1,
    ada_real_err_train,
    label="AdaBoost Train Error",
    color="green",
)

ax.set_ylim((0.0, 0.5))
ax.set_xlabel("n_estimators")
ax.set_ylabel("error rate")

leg = ax.legend(loc="upper right", fancybox=True)
leg.get_frame().set_alpha(0.7)

plt.title(name)
plt.show()

# %% [markdown]
# ## KNN
# https://machinelearningknowledge.ai/knn-classifier-in-sklearn-using-gridsearchcv-with-example/

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### 1. Departure

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

k_range = list(range(1, 16))
param_grid = dict(n_neighbors=k_range)
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search = grid.fit(X_train, y_train["dep"])
accuracy = grid_search.best_score_ *100
print("Accuracy for our training dataset with tuning is : {:.2f}%".format(accuracy) )
# Out:
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed: 131.6min finished
# Accuracy for our training dataset with tuning is : 79.55%

# %%
y_pred = grid.predict(X_test)
test_accuracy = accuracy_score(y_test["dep"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# Accuracy for our testing dataset with tuning is : 79.46%

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test["dep"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Departure)')
# Out:
# Confusion matrix, without normalization
# [[526019    582    145     63   2498]
#  [ 44137    253     40     23    593]
#  [ 24072    111     59     14    485]
#  [ 15530     73     35     16    381]
#  [ 47502    189     75     32   2098]]

# %% [markdown]
# ## Random Forest
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 <br>
# https://machinelearningmastery.com/random-forest-ensemble-in-python/

# %% [markdown]
# #### 1. Classification - dep

# %%
from sklearn.ensemble import RandomForestClassifier
rf_dep = RandomForestClassifier(n_estimators=20)
rf_dep.fit(X_train, y_train["dep"])
# make a single prediction
y_pred = rf_dep.predict(X_test)
# Calculate the absolute errors
error_rate = len(y_pred[y_pred!=y_test["dep"]])/len(y_pred)
print("Error Rate:", error_rate)

train_accuracy = accuracy_score(y_train["dep"],rf_dep.predict(X_train))*100
print("Accuracy for our training dataset with tuning is : {:.2f}%".format(train_accuracy) )

test_accuracy = accuracy_score(y_test["dep"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# Error Rate: 0.17701139054922746
# Accuracy for our training dataset with tuning is : 99.27%
# Accuracy for our testing dataset with tuning is : 82.30%

# %%
cnf_matrix = confusion_matrix(y_test["dep"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Departure)')
# Out:
# Confusion matrix, without normalization
# [[522565   2121    743    409   3469]
#  [ 37504   5975    258    113   1196]
#  [ 19803    399   3322    126   1091]
#  [ 12512    268    146   2118    991]
#  [ 35267    672    364    265  13328]]

# %% [markdown]
# ## Random Forest (# of estimators: 50)
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 <br>
# https://machinelearningmastery.com/random-forest-ensemble-in-python/

# %% [markdown]
# #### 1. Classification - dep

# %%
from sklearn.ensemble import RandomForestClassifier
rf_dep = RandomForestClassifier(n_estimators=50)
rf_dep.fit(X_train, y_train["dep"])
# make a single prediction
y_pred = rf_dep.predict(X_test)
# Calculate the absolute errors
error_rate = len(y_pred[y_pred!=y_test["dep"]])/len(y_pred)
print("Error Rate:", error_rate)

train_accuracy = accuracy_score(y_train["dep"],rf_dep.predict(X_train))*100
print("Accuracy for our training dataset with tuning is : {:.2f}%".format(train_accuracy) )

test_accuracy = accuracy_score(y_test["dep"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# Error Rate: 0.1731934889665802
# Accuracy for our training dataset with tuning is : 99.93%
# Accuracy for our testing dataset with tuning is : 82.68%

# %%
cnf_matrix = confusion_matrix(y_test["dep"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Departure)')
# Out:
# Confusion matrix, without normalization
# [[524627   1304    485    230   2661]
#  [ 37597   6078    172     87   1112]
#  [ 19910    300   3396     84   1051]
#  [ 12584    197    124   2187    943]
#  [ 35418    466    243    210  13559]]

# %% [markdown]
# # Select K Best - Arrival

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

error_table_Arrival = np.empty((0,4))

for i in range(1,X.shape[1]+1):
    FEATURE_NUM = i
    print("# of feature:",str(i))
    features_arr,z_clf = select_K_Best(X,y["arr"],"clf",FEATURE_NUM)
    X_input = X[features_arr]
    X_train, X_test, y_train, y_test = train_test_split(X_input, y["arr"], test_size=0.3, random_state=1) # 70% training and 30% test
    
    rf_dep = RandomForestClassifier(n_estimators=20)
    rf_dep.fit(X_train, y_train)
    # make a single prediction
    y_pred = rf_dep.predict(X_test)
    # Calculate the absolute errors
    error_rate = len(y_pred[y_pred!=y_test])/len(y_pred)
    print("Error Rate:", error_rate)

    train_accuracy = accuracy_score(y_train,rf_dep.predict(X_train))*100
    print("Accuracy for our training dataset with tuning is : {:.2f}%".format(train_accuracy) )

    test_accuracy = accuracy_score(y_test,y_pred)*100
    print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
    
    error_table_Arrival = np.vstack((error_table_Arrival, np.array([i, error_rate, train_accuracy, test_accuracy])))
# Out:
# # of feature: 1
# Error Rate: 0.20900417277545957
# Accuracy for our training dataset with tuning is : 79.19%
# Accuracy for our testing dataset with tuning is : 79.10%
# # of feature: 2
# Error Rate: 0.2123198376000902
# Accuracy for our training dataset with tuning is : 79.46%
# Accuracy for our testing dataset with tuning is : 78.77%
# # of feature: 3
# Error Rate: 0.2214277658734634
# Accuracy for our training dataset with tuning is : 85.96%
# Accuracy for our testing dataset with tuning is : 77.86%
# # of feature: 4
# Error Rate: 0.21948798917333934
# Accuracy for our training dataset with tuning is : 86.26%
# Accuracy for our testing dataset with tuning is : 78.05%
# # of feature: 5
# Error Rate: 0.21897673019811284
# Accuracy for our training dataset with tuning is : 86.40%
# Accuracy for our testing dataset with tuning is : 78.10%
# # of feature: 6
# Error Rate: 0.2265012593511522
# Accuracy for our training dataset with tuning is : 94.54%
# Accuracy for our testing dataset with tuning is : 77.35%
# # of feature: 7
# Error Rate: 0.22628773354385173
# Accuracy for our training dataset with tuning is : 94.62%
# Accuracy for our testing dataset with tuning is : 77.37%
# # of feature: 8
# Error Rate: 0.22571181534528778
# Accuracy for our training dataset with tuning is : 94.67%
# Accuracy for our testing dataset with tuning is : 77.43%
# # of feature: 9
# Error Rate: 0.2247389195894891
# Accuracy for our training dataset with tuning is : 95.40%
# Accuracy for our testing dataset with tuning is : 77.53%
# # of feature: 10
# Error Rate: 0.22492688244802828
# Accuracy for our training dataset with tuning is : 95.40%
# Accuracy for our testing dataset with tuning is : 77.51%
# # of feature: 11
# Error Rate: 0.22472839366941091
# Accuracy for our training dataset with tuning is : 95.41%
# Accuracy for our testing dataset with tuning is : 77.53%
# # of feature: 12
# Error Rate: 0.2251343934438555
# Accuracy for our training dataset with tuning is : 95.40%
# Accuracy for our testing dataset with tuning is : 77.49%
# # of feature: 13
# Error Rate: 0.22500808240291717
# Accuracy for our training dataset with tuning is : 95.41%
# Accuracy for our testing dataset with tuning is : 77.50%
# # of feature: 14
# Error Rate: 0.22579151159730837
# Accuracy for our training dataset with tuning is : 95.42%
# Accuracy for our testing dataset with tuning is : 77.42%
# # of feature: 15
# Error Rate: 0.22559753392729598
# Accuracy for our training dataset with tuning is : 95.41%
# Accuracy for our testing dataset with tuning is : 77.44%
# # of feature: 16
# Error Rate: 0.22662005187774895
# Accuracy for our training dataset with tuning is : 95.43%
# Accuracy for our testing dataset with tuning is : 77.34%
# # of feature: 17
# Error Rate: 0.22600654110747717
# Accuracy for our training dataset with tuning is : 95.42%
# Accuracy for our testing dataset with tuning is : 77.40%
# # of feature: 18
# Error Rate: 0.22709672568700426
# Accuracy for our training dataset with tuning is : 95.45%
# Accuracy for our testing dataset with tuning is : 77.29%
# # of feature: 19
# Error Rate: 0.22685763693094244
# Accuracy for our training dataset with tuning is : 95.44%
# Accuracy for our testing dataset with tuning is : 77.31%
# # of feature: 20
# Error Rate: 0.1998646667418518
# Accuracy for our training dataset with tuning is : 98.49%
# Accuracy for our testing dataset with tuning is : 80.01%
# # of feature: 21
# Error Rate: 0.19993082966805759
# Accuracy for our training dataset with tuning is : 98.50%
# Accuracy for our testing dataset with tuning is : 80.01%
# # of feature: 22
# Error Rate: 0.19932333370925906
# Accuracy for our training dataset with tuning is : 98.49%
# Accuracy for our testing dataset with tuning is : 80.07%
# # of feature: 23
# Error Rate: 0.1996842223976542
# Accuracy for our training dataset with tuning is : 98.50%
# Accuracy for our testing dataset with tuning is : 80.03%
# # of feature: 24
# Error Rate: 0.19268147813991957
# Accuracy for our training dataset with tuning is : 99.02%
# Accuracy for our testing dataset with tuning is : 80.73%
# # of feature: 25
# Error Rate: 0.19245592270967257
# Accuracy for our training dataset with tuning is : 99.02%
# Accuracy for our testing dataset with tuning is : 80.75%
# # of feature: 26
# Error Rate: 0.19198676741475884
# Accuracy for our training dataset with tuning is : 99.03%
# Accuracy for our testing dataset with tuning is : 80.80%
# # of feature: 27
# Error Rate: 0.19224690801097702
# Accuracy for our training dataset with tuning is : 99.01%
# Accuracy for our testing dataset with tuning is : 80.78%
# # of feature: 28
# Error Rate: 0.19236419683470546
# Accuracy for our training dataset with tuning is : 99.02%
# Accuracy for our testing dataset with tuning is : 80.76%
# # of feature: 29
# Error Rate: 0.1924363745723845
# Accuracy for our training dataset with tuning is : 99.02%
# Accuracy for our testing dataset with tuning is : 80.76%
# # of feature: 30
# Error Rate: 0.1924814856584339
# Accuracy for our training dataset with tuning is : 99.04%
# Accuracy for our testing dataset with tuning is : 80.75%
# # of feature: 31
# Error Rate: 0.19215818954174654
# Accuracy for our training dataset with tuning is : 99.04%
# Accuracy for our testing dataset with tuning is : 80.78%
# # of feature: 32
# Error Rate: 0.1926874929513928
# Accuracy for our training dataset with tuning is : 99.08%
# Accuracy for our testing dataset with tuning is : 80.73%
# # of feature: 33
# Error Rate: 0.19236570053757376
# Accuracy for our training dataset with tuning is : 99.07%
# Accuracy for our testing dataset with tuning is : 80.76%
# # of feature: 34
# Error Rate: 0.19198526371189054
# Accuracy for our training dataset with tuning is : 99.06%
# Accuracy for our testing dataset with tuning is : 80.80%
# # of feature: 35
# Error Rate: 0.19201383406638847
# Accuracy for our training dataset with tuning is : 99.08%
# Accuracy for our testing dataset with tuning is : 80.80%
# # of feature: 36
# Error Rate: 0.19112514567121536
# Accuracy for our training dataset with tuning is : 99.09%
# Accuracy for our testing dataset with tuning is : 80.89%
# # of feature: 37
# Error Rate: 0.1900830795834743
# Accuracy for our training dataset with tuning is : 99.08%
# Accuracy for our testing dataset with tuning is : 80.99%
# # of feature: 38
# Error Rate: 0.19000789444005864
# Accuracy for our training dataset with tuning is : 99.10%
# Accuracy for our testing dataset with tuning is : 81.00%
# # of feature: 39
# Error Rate: 0.18342618698545168
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.66%
# # of feature: 40
# Error Rate: 0.1820653358896282
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.79%
# # of feature: 41
# Error Rate: 0.18231194316003158
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 42
# Error Rate: 0.1821330025187023
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.79%
# # of feature: 43
# Error Rate: 0.18232096537724146
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 44
# Error Rate: 0.1823600616518176
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.76%
# # of feature: 45
# Error Rate: 0.18226232096537723
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 46
# Error Rate: 0.18231344686289988
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 47
# Error Rate: 0.1823375061087929
# Accuracy for our training dataset with tuning is : 99.26%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 48
# Error Rate: 0.1827480169918424
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.73%
# # of feature: 49
# Error Rate: 0.18224126912522084
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.78%
# # of feature: 50
# Error Rate: 0.1823495357317394
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 51
# Error Rate: 0.18221871358219616
# Accuracy for our training dataset with tuning is : 99.26%
# Accuracy for our testing dataset with tuning is : 81.78%
# # of feature: 52
# Error Rate: 0.18233449870305626
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 53
# Error Rate: 0.18222021728506446
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.78%
# # of feature: 54
# Error Rate: 0.18252847637306868
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.75%
# # of feature: 55
# Error Rate: 0.18267132814555845
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.73%
# # of feature: 56
# Error Rate: 0.18190895079132363
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.81%
# # of feature: 57
# Error Rate: 0.18196609150031953
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.80%
# # of feature: 58
# Error Rate: 0.18269989850005638
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.73%
# # of feature: 59
# Error Rate: 0.18223826171948423
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.78%
# # of feature: 60
# Error Rate: 0.18249088380136086
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.75%
# # of feature: 61
# Error Rate: 0.1825735874591181
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.74%
# # of feature: 62
# Error Rate: 0.18283222435246796
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.72%
# # of feature: 63
# Error Rate: 0.1829074094958836
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.71%
# # of feature: 64
# Error Rate: 0.18232246908010977
# Accuracy for our training dataset with tuning is : 99.26%
# Accuracy for our testing dataset with tuning is : 81.77%
# # of feature: 65
# Error Rate: 0.18247735047554603
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.75%
# # of feature: 66
# Error Rate: 0.18246682455546784
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.75%
# # of feature: 67
# Error Rate: 0.18260516521935266
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.74%
# # of feature: 68
# Error Rate: 0.18264275779106048
# Accuracy for our training dataset with tuning is : 99.23%
# Accuracy for our testing dataset with tuning is : 81.74%
# # of feature: 69
# Error Rate: 0.1826337355738506
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.74%
# # of feature: 70
# Error Rate: 0.182505920830044
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.75%
# # of feature: 71
# Error Rate: 0.18264877260253373
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.74%
# # of feature: 72
# Error Rate: 0.1825089282357806
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.75%
# # of feature: 73
# Error Rate: 0.1830186835081388
# Accuracy for our training dataset with tuning is : 99.25%
# Accuracy for our testing dataset with tuning is : 81.70%
# # of feature: 74
# Error Rate: 0.18299612796511408
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.70%
# # of feature: 75
# Error Rate: 0.18275403180331568
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.72%
# # of feature: 76
# Error Rate: 0.18282771324386302
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.72%
# # of feature: 77
# Error Rate: 0.1827450095861058
# Accuracy for our training dataset with tuning is : 99.24%
# Accuracy for our testing dataset with tuning is : 81.73%
# # of feature: 78
# Error Rate: 0.17872561181910454
# Accuracy for our training dataset with tuning is : 99.31%
# Accuracy for our testing dataset with tuning is : 82.13%
# # of feature: 79
# Error Rate: 0.1783451749934213
# Accuracy for our training dataset with tuning is : 99.31%
# Accuracy for our testing dataset with tuning is : 82.17%
# # of feature: 80
# Error Rate: 0.17856772301793167
# Accuracy for our training dataset with tuning is : 99.31%
# Accuracy for our testing dataset with tuning is : 82.14%
# # of feature: 81
# Error Rate: 0.1783557009134995
# Accuracy for our training dataset with tuning is : 99.31%
# Accuracy for our testing dataset with tuning is : 82.16%
# # of feature: 82
# Error Rate: 0.1782098417352731
# Accuracy for our training dataset with tuning is : 99.30%
# Accuracy for our testing dataset with tuning is : 82.18%
# # of feature: 83
# Error Rate: 0.17832863426186985
# Accuracy for our training dataset with tuning is : 99.30%
# Accuracy for our testing dataset with tuning is : 82.17%
# # of feature: 84
# Error Rate: 0.17783541972106312
# Accuracy for our training dataset with tuning is : 99.31%
# Accuracy for our testing dataset with tuning is : 82.22%
# # of feature: 85
# Error Rate: 0.17847449344009625
# Accuracy for our training dataset with tuning is : 99.32%
# Accuracy for our testing dataset with tuning is : 82.15%

# %%
plt.plot(
    error_table_Arrival[:,0],
    error_table_Arrival[:,1],
    label="Error Rate"
)
plt.ylabel('Error Rate')
plt.xlabel('# of best feature')
# Out:
# Text(0.5, 0, '# of best feature')

# %%
error_table_Arrival[np.argmin(error_table[:,1]),:]
# Out:
# array([84.  ,  0.18, 99.31, 82.22])

# %%
FEATURE_NUM = 84
features_arr,z_clf = select_K_Best(X,y["arr"],"clf",FEATURE_NUM)
X_input = X[features_arr]
X_train, X_test, y_train, y_test = train_test_split(X_input, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
print("Selected Top",FEATURE_NUM," Features for Classification :",list(features_arr))
# Out:
# Selected Top 84  Features for Classification : ['LATITUDE', 'LONGITUDE', 'MONTH', 'DAY_OF_MONTH', 'PLANE_AGE', 'AWND', 'PRCP', 'SNOW', 'TMAX', 'TAVG', 'DISTANCE', 'AIRLINE_ID 0', 'AIRLINE_ID 1', 'AIRLINE_ID 2', 'AIRLINE_ID 3', 'AIRLINE_ID 4', 'AIRLINE_ID 5', 'AIRLINE_ID 6', 'AIRLINE_ID 7', 'AIRLINE_ID 8', 'AIRLINE_ID 9', 'AIRLINE_ID 10', 'AIRLINE_ID 11', 'DEST_AIRPORT_ID 0', 'DEST_AIRPORT_ID 1', 'DEST_AIRPORT_ID 2', 'DEST_AIRPORT_ID 3', 'DEST_AIRPORT_ID 4', 'DEST_AIRPORT_ID 5', 'DEST_AIRPORT_ID 6', 'DEST_AIRPORT_ID 7', 'DEST_AIRPORT_ID 8', 'DEST_AIRPORT_ID 9', 'DEST_AIRPORT_ID 10', 'DEST_AIRPORT_ID 11', 'DEST_AIRPORT_ID 12', 'DEST_AIRPORT_ID 13', 'DEST_AIRPORT_ID 14', 'DEST_AIRPORT_ID 15', 'DEST_AIRPORT_ID 16', 'DEST_AIRPORT_ID 17', 'DEST_AIRPORT_ID 18', 'DEST_AIRPORT_ID 20', 'DEST_AIRPORT_ID 21', 'DEST_AIRPORT_ID 22', 'DEST_AIRPORT_ID 23', 'DEST_AIRPORT_ID 24', 'DEST_AIRPORT_ID 25', 'DEST_AIRPORT_ID 26', 'DEST_AIRPORT_ID 27', 'DEST_AIRPORT_ID 28', 'DEST_AIRPORT_ID 29', 'ORIGIN_AIRPORT_ID 0', 'ORIGIN_AIRPORT_ID 1', 'ORIGIN_AIRPORT_ID 2', 'ORIGIN_AIRPORT_ID 3', 'ORIGIN_AIRPORT_ID 4', 'ORIGIN_AIRPORT_ID 5', 'ORIGIN_AIRPORT_ID 6', 'ORIGIN_AIRPORT_ID 7', 'ORIGIN_AIRPORT_ID 8', 'ORIGIN_AIRPORT_ID 9', 'ORIGIN_AIRPORT_ID 10', 'ORIGIN_AIRPORT_ID 11', 'ORIGIN_AIRPORT_ID 12', 'ORIGIN_AIRPORT_ID 13', 'ORIGIN_AIRPORT_ID 14', 'ORIGIN_AIRPORT_ID 15', 'ORIGIN_AIRPORT_ID 16', 'ORIGIN_AIRPORT_ID 17', 'ORIGIN_AIRPORT_ID 18', 'ORIGIN_AIRPORT_ID 19', 'ORIGIN_AIRPORT_ID 20', 'ORIGIN_AIRPORT_ID 21', 'ORIGIN_AIRPORT_ID 22', 'ORIGIN_AIRPORT_ID 23', 'ORIGIN_AIRPORT_ID 24', 'ORIGIN_AIRPORT_ID 25', 'ORIGIN_AIRPORT_ID 26', 'ORIGIN_AIRPORT_ID 27', 'ORIGIN_AIRPORT_ID 28', 'ORIGIN_AIRPORT_ID 29', 'CRS_ARR_TIME_MIN', 'CRS_DEP_TIME_MIN']

# %% [markdown]
# ### Base learner: Decision Tree

# %% [markdown]
# #### 2. Arrival

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
model = abc.fit(X_train, y_train["arr"])

#Predict the response for test dataset
y_pred = model.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test["arr"], y_pred))
# Out:
# Accuracy: 0.7916168565091538

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test["arr"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Arrival)')
# Out:
# Confusion matrix, without normalization
# [[525358      0      0      0    676]
#  [ 47053      0      0      0    264]
#  [ 25079      0      0      0    203]
#  [ 16067      0      0      0    175]
#  [ 49063      0      0      0   1087]]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import zero_one_loss
from sklearn.ensemble import AdaBoostClassifier

name = "arr"

n_estimators = 400
learning_rate = 0.5

dt_stump = DecisionTreeClassifier(max_depth=1, min_samples_leaf=1)
dt_stump.fit(X_train, y_train[name])
dt_stump_err = 1.0 - dt_stump.score(X_test, y_test[name])

dt = DecisionTreeClassifier(max_depth=9, min_samples_leaf=1)
dt.fit(X_train, y_train[name])
dt_err = 1.0 - dt.score(X_test, y_test[name])


ada_real = AdaBoostClassifier(
    base_estimator=dt_stump,
    learning_rate=learning_rate,
    n_estimators=n_estimators,
    algorithm="SAMME.R",
)
ada_real.fit(X_train, y_train[name])

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot([1, n_estimators], [dt_stump_err] * 2, "k-", label="Decision Stump Error")
ax.plot([1, n_estimators], [dt_err] * 2, "k--", label="Decision Tree Error")

ada_real_err = np.zeros((n_estimators,))
for i, y_pred in enumerate(ada_real.staged_predict(X_test)):
    ada_real_err[i] = zero_one_loss(y_pred, y_test[name])

ada_real_err_train = np.zeros((n_estimators,))
for i, y_pred in enumerate(ada_real.staged_predict(X_train)):
    ada_real_err_train[i] = zero_one_loss(y_pred, y_train[name])


ax.plot(
    np.arange(n_estimators) + 1,
    ada_real_err,
    label="AdaBoost Test Error",
    color="orange",
)
ax.plot(
    np.arange(n_estimators) + 1,
    ada_real_err_train,
    label="AdaBoost Train Error",
    color="green",
)

ax.set_ylim((0.0, 0.5))
ax.set_xlabel("n_estimators")
ax.set_ylabel("error rate")

leg = ax.legend(loc="upper right", fancybox=True)
leg.get_frame().set_alpha(0.7)

plt.title(name)
plt.show()

# %% [markdown]
# ## KNN
# https://machinelearningknowledge.ai/knn-classifier-in-sklearn-using-gridsearchcv-with-example/

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### 2. Arrival

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

k_range = list(range(1, 16))
param_grid = dict(n_neighbors=k_range)
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search = grid.fit(X_train, y_train["arr"])
accuracy = grid_search.best_score_ *100
print("Accuracy for our training dataset with tuning is : {:.2f}%".format(accuracy) )

y_pred = grid.predict(X_test)
test_accuracy = accuracy_score(y_test["arr"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed: 103.3min finished
# Accuracy for our training dataset with tuning is : 79.03%
# Accuracy for our testing dataset with tuning is : 78.96%

# %%
grid_search.best_params_
# Out:
# {'n_neighbors': 15}

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test["arr"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Arrival)')
# Out:
# Confusion matrix, without normalization
# [[522754    544    136     68   2532]
#  [ 46389    236     43     11    638]
#  [ 24632    100     47     15    488]
#  [ 15738     81     25     14    384]
#  [ 47785    199     55     28   2083]]

# %% [markdown]
# ## Random Forest
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 <br>
# https://machinelearningmastery.com/random-forest-ensemble-in-python/

# %% [markdown]
# #### 2. Classification - arr

# %%
from sklearn.ensemble import RandomForestClassifier
rf_dep = RandomForestClassifier(n_estimators=20)
rf_dep.fit(X_train, y_train["arr"])
# make a single prediction
y_pred = rf_dep.predict(X_test)
# Calculate the absolute errors
error_rate = len(y_pred[y_pred!=y_test["arr"]])/len(y_pred)
print("Error Rate:", error_rate)

train_accuracy = accuracy_score(y_train["arr"],rf_dep.predict(X_train))*100
print("Accuracy for our training dataset with tuning is : {:.2f}%".format(train_accuracy) )

test_accuracy = accuracy_score(y_test["arr"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# Error Rate: 0.1780730047742566
# Accuracy for our training dataset with tuning is : 99.30%
# Accuracy for our testing dataset with tuning is : 82.19%

# %%
cnf_matrix = confusion_matrix(y_test["arr"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Arrival)')
# Out:
# Confusion matrix, without normalization
# [[519386   2089    836    401   3322]
#  [ 39107   6222    369    157   1462]
#  [ 19725    549   3461    148   1399]
#  [ 12203    329    210   2192   1308]
#  [ 33096    794    537    382  15341]]

# %% [markdown]
# ## Random Forest (# of estimators: 50)
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 <br>
# https://machinelearningmastery.com/random-forest-ensemble-in-python/

# %% [markdown]
# #### 2. Classification - arr

# %%
from sklearn.ensemble import RandomForestClassifier
rf_dep = RandomForestClassifier(n_estimators=50)
rf_dep.fit(X_train, y_train["arr"])
# make a single prediction
y_pred = rf_dep.predict(X_test)
# Calculate the absolute errors
error_rate = len(y_pred[y_pred!=y_test["arr"]])/len(y_pred)
print("Error Rate:", error_rate)

train_accuracy = accuracy_score(y_train["arr"],rf_dep.predict(X_train))*100
print("Accuracy for our training dataset with tuning is : {:.2f}%".format(train_accuracy) )

test_accuracy = accuracy_score(y_test["arr"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# Error Rate: 0.1749768805683997
# Accuracy for our training dataset with tuning is : 99.93%
# Accuracy for our testing dataset with tuning is : 82.50%

# %%
cnf_matrix = confusion_matrix(y_test["arr"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Arrival)')
# Out:
# Confusion matrix, without normalization
# [[521138   1346    536    236   2778]
#  [ 39402   6255    261    129   1270]
#  [ 19959    368   3495    116   1344]
#  [ 12312    238    160   2233   1299]
#  [ 33338    578    415    279  15540]]

# %% [markdown]
# ## XGBoost
# https://www.datacamp.com/community/tutorials/xgboost-in-python

# %% [markdown]
# #### 2. Classification - arr

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
data_dmatrix = xgb.DMatrix(data=X_train,label=y_train["arr"])

# %%
parameters = {'n_estimators':list(range(1,100))}
xg_clf = xgb.XGBClassifier(colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10)
clf = GridSearchCV(xg_clf, parameters)
clf.fit(X_train,y_train["arr"])

sorted(clf.cv_results_.keys())
# Out:
# /Users/tracyliu/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:22:10] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:15] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:23] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:28] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:32] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:38] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:44] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:50] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:22:56] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:03] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:11] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:27] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:35] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:44] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:23:54] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:24:04] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:24:14] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:24:25] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:24:35] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:24:47] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:24:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:25:11] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:25:23] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:25:35] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:25:49] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:26:03] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:26:17] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:26:32] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:26:46] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:27:02] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:27:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:27:35] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:27:51] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:28:08] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:28:26] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:28:44] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:29:02] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:29:21] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:29:40] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:30:01] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:30:21] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:30:42] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:31:03] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:31:24] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:31:46] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:32:09] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:32:33] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:32:55] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:33:18] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:33:43] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:34:09] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:34:38] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:35:12] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:35:39] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:36:06] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:36:32] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:36:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:37:27] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:37:54] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:38:23] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:38:52] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:39:22] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:39:52] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:40:23] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:40:54] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:41:26] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:41:58] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:42:31] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:43:03] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:43:37] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:44:11] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:44:45] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:20] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:54] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:46:32] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:47:08] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:47:45] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:48:21] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:48:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:49:39] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:50:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:51:00] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:51:41] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:52:22] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:53:08] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:53:55] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:54:41] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:55:25] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:56:12] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:57:00] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:57:47] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:58:35] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:59:22] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:00:10] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:01:01] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:01:55] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:02:52] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:03:48] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:04:45] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:05:47] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:06:46] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:07:45] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:08:44] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:09:44] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:10:47] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:11:49] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:12:52] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:13:56] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:15:01] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:16:09] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:17:15] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:18:22] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:19:29] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:20:37] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:21:49] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:22:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:24:10] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:25:21] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:26:34] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:27:46] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:28:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:30:11] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:31:29] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:32:43] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:34:00] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:35:15] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:36:33] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:37:49] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:39:05] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
# [02:24:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:27:29] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:30:39] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:33:51] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:37:03] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:40:15] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:43:28] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:46:40] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:49:54] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:53:09] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:56:23] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:59:39] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:02:55] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:06:12] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:09:27] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:12:43] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:15:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:19:15] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:22:31] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:25:47] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:29:04] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:32:22] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:35:39] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:38:59] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:42:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:45:40] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:49:00] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:52:19] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:55:41] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:59:02] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:02:24] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:05:45] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:09:07] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:12:29] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:15:50] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:19:13] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:22:35] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:25:58] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:29:24] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:32:49] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:36:14] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:39:41] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:43:08] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_n_estimators',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
clf.best_params_
# Out:
# {'n_estimators': 99}

# %%
xg_clf = xgb.XGBClassifier(colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 90)
xg_clf.fit(X_train,y_train["arr"])
y_pred = xg_clf.predict(X_test)
test_accuracy = accuracy_score(y_test["arr"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# [11:33:48] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy for our testing dataset with tuning is : 79.35%

# %%
cnf_matrix = confusion_matrix(y_test["arr"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Arrival)')
# Out:
# Confusion matrix, without normalization
# [[525444      0      0      0    590]
#  [ 47030      0      0      0    287]
#  [ 24989      0      0      0    293]
#  [ 15993      0      0      0    249]
#  [ 47885      0      0      0   2265]]

# %%
xg_clf = xgb.XGBClassifier(colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 90)
xg_clf.fit(X_train,y_train["dep"])
y_pred = xg_clf.predict(X_test)
test_accuracy = accuracy_score(y_test["dep"],y_pred)*100
print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy) )
# Out:
# [11:37:51] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy for our testing dataset with tuning is : 79.75%

# %%
cnf_matrix = confusion_matrix(y_test["dep"], y_pred, labels=[0, 15, 30, 45, 60])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0, 15, 30, 45, 60],
                      title='Confusion matrix (Departure)')
# Out:
# Confusion matrix, without normalization
# [[528926      0      0      0    381]
#  [ 44874      0      0      0    172]
#  [ 24611      0      0      0    130]
#  [ 15874      0      0      0    161]
#  [ 48491      0      0      0   1405]]
